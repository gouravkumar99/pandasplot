# %%
import pandas as pd
import numpy as np

# %%
mydata ={'fruits':['apple','banana','orange'],
        'price':[40,60,30]}

# %%
mylist = pd.DataFrame(mydata)
mylist
# Out:
#    fruits  price
# 0   apple     40
# 1  banana     60
# 2  orange     30

# %%
a = ['a','b','c']
print(pd.Series(a))
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
mydata = pd.Series(a,index=['x','y','z'])
mydata
# Out:
# x    a
# y    b
# z    c
# dtype: object

# %%
mydata['z']
# Out:
# 'c'

# %%
flist={'apple':'Rs.50kg','orange':'Rs.60kg','graps':'Rs.70kg'}
fruits = pd.Series(flist)
print(fruits)
print(flist.keys())
# Out:
# apple     Rs.50kg
# orange    Rs.60kg
# graps     Rs.70kg
# dtype: object
# dict_keys(['apple', 'orange', 'graps'])

# %%
fruits['graps']
# Out:
# 'Rs.70kg'

# %%
print(pd.Series(flist,index=['apple','graps']))
# Out:
# apple    Rs.50kg
# graps    Rs.70kg
# dtype: object

# %%
data={'list':flist.keys(),
    'price':flist.values()
    
}
pd.DataFrame(data,index=[1,2,3])
# Out:
#      list    price
# 1   apple  Rs.50kg
# 2  orange  Rs.60kg
# 3   graps  Rs.70kg

# %%
##DataFrame

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# # Use the named index in the loc attribute to return the specified row(s).

# %%
df.loc[1]
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %% [markdown]
# # Load Files Into a DataFrame

# %%
link  = r'C:\Users\goura\Downloads\IPL-Data-Analysis-master\IPL-Data-Analysis-master\matches.csv'
df = pd.read_csv(link)
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # use to_string() to print the entire DataFrame.

# %%
print(df.to_string())
# Out:
#         id  season            city        date                        team1                        team2                  toss_winner toss_decision     result  dl_applied                       winner  win_by_runs  win_by_wickets    player_of_match                                                 venue                umpire1                umpire2                  umpire3
# 0        1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad  Royal Challengers Bangalore  Royal Challengers Bangalore         field     normal           0          Sunrisers Hyderabad           35               0       Yuvraj Singh             Rajiv Gandhi International Stadium, Uppal            AY Dandekar               NJ Llong                      NaN
# ...

# %%
link2 = r'https://www.garvthakur.com/CenterLized/childtAccount/e8fb2a12-3592-4ba0-a849-514de8abbe1d/AliceBlue'
df = pd.read_json(link2)
df
# Out:
#                                                 data
# 0  {'broker': 'AliceBlue', 'clientID': '237562', ...
# 1  {'broker': 'AliceBlue', 'clientID': 'AB041270'...
# 2  {'broker': 'AliceBlue', 'clientID': 'MN38025',...
# 3  {'broker': 'AliceBlue', 'clientID': '420795', ...

# %% [markdown]
# # Pandas - Analyzing DataFrames

# %%
link  = r'C:\Users\goura\Downloads\IPL-Data-Analysis-master\IPL-Data-Analysis-master\matches.csv'
df = pd.read_csv(link)
# starting 5 rows of data use .head()
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# last 5 rows of dataa use .tail()
df.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
# use .info() all information of your data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # Cleaning Data

# %%
new_df = df.dropna()
new_df
# Out:
#         id  season           city      date                        team1  \
# 636   7894    2018         Mumbai  07/04/18               Mumbai Indians
# 637   7895    2018         Mohali  08/04/18             Delhi Daredevils
# 638   7896    2018        Kolkata  08/04/18  Royal Challengers Bangalore
# 639   7897    2018      Hyderabad  09/04/18             Rajasthan Royals
# 640   7898    2018        Chennai  10/04/18        Kolkata Knight Riders
# ..     ...     ...            ...       ...                          ...
# 750  11346    2019         Mohali  05/05/19          Chennai Super Kings
# 751  11347    2019         Mumbai  05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19          Chennai Super Kings
# 754  11414    2019  Visakhapatnam  10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
link = r"C:\Users\goura\Downloads\dirtydata.csv"
df = pd.read_csv(link)
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
df.to_string()
# Out:
# "    Duration          Date  Pulse  Maxpulse  Calories\n0         60  '2020/12/01'    110       130     409.1\n1         60  '2020/12/02'    117       145     479.0\n2         60  '2020/12/03'    103       135     340.0\n3         45  '2020/12/04'    109       175     282.4\n4         45  '2020/12/05'    117       148     406.0\n5         60  '2020/12/06'    102       127     300.0\n6         60  '2020/12/07'    110       136     374.0\n7        450  '2020/12/08'    104       134     253.3\n8         30  '2020/12/09'    109       133     195.1\n9         60  '2020/12/10'     98       124     269.0\n10        60  '2020/12/11'    103       147     329.3\n11        60  '2020/12/12'    100       120     250.7\n12        60  '2020/12/12'    100       120     250.7\n13        60  '2020/12/13'    106       128     345.3\n14        60  '2020/12/14'    104       132     379.3\n15        60  '2020/12/15'     98       123     275.0\n16        60  '2020/12/16'     98       120     215.2\n17     
# ...

# %% [markdown]
# # dropna() method returns a new DataFrame, and will not change the original

# %%
new_df = df.dropna()
new_df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# Remove all rows with NULL values

df.dropna(inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# the dropna(inplace = True) will NOT return a new DataFrame, 
# but it will remove all rows containg NULL values from the original DataFrame.

# %%
link = r"C:\Users\goura\Downloads\dirtydata.csv"
df = pd.read_csv(link)
# df
df.fillna(130,inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
link = r"C:\Users\goura\Downloads\dirtydata.csv"
df = pd.read_csv(link)
# df
df['Calories'].fillna(150,inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
link = r"C:\Users\goura\Downloads\dirtydata.csv"
df = pd.read_csv(link)
print(df['Calories'].mean())
df
# Out:
# 304.68
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
link = r"C:\Users\goura\Downloads\dirtydata.csv"
df = pd.read_csv(link)
val = df['Calories'].mean()
df['Calories'].mode()[0]
df['Calories'].median()
df['Calories'].fillna(val,inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
link = r"C:\Users\goura\Downloads\dirtydata.csv"
df = pd.read_csv(link)

df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.loc[7,'Duration']
# Out:
# 450

# %%
df.loc[7,'Duration']=45
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
import pandas as pd

data = {
    
"data": [
{
"broker": "AliceBlue",
"clientID": "237562",
"password": "avdh0421",
"fa": "1978",
"redirect_uri": "",
"email": "",
"apP__SOURCE": "",
"encryptioN_KEY": "",
"multiplier": "1",
"appID": "",
"secretkey": "",
"userName": "Gourav",
"parent": "MN101019"
},
{
"broker": "AliceBlue",
"clientID": "AB041270",
"password": "eshan11",
"fa": "1976",
"redirect_uri": "",
"email": "",
"apP__SOURCE": "",
"encryptioN_KEY": "",
"multiplier": "1",
"appID": "",
"secretkey": "",
"userName": "Gourav",
"parent": "MN101019"
},
{
"broker": "AliceBlue",
"clientID": "MN38025",
"password": "Mhk@9599",
"fa": "1995",
"redirect_uri": "",
"email": "",
"apP__SOURCE": "",
"encryptioN_KEY": "",
"multiplier": "1",
"appID": "",
"secretkey": "",
"userName": "Gourav",
"parent": "MN101019"
},
{
"broker": "AliceBlue",
"clientID": "420795",
"password": "Gaurav987@",
"fa": "1983",
"redirect_uri": "",
"email": "",
"apP__SOURCE": "",
"encryptioN_KEY": "",
"multiplier": "1",
"appID": "",
"secretkey": "",
"userName": "Gourav",
"parent": "MN101019"
}
]
}
df = pd.DataFrame(data["data"])

df = df.drop(['redirect_uri', 'email','apP__SOURCE','encryptioN_KEY','appID','secretkey'], axis=1)
df
# Out:
#       broker  clientID    password    fa multiplier userName    parent
# 0  AliceBlue    237562    avdh0421  1978          1   Gourav  MN101019
# 1  AliceBlue  AB041270     eshan11  1976          1   Gourav  MN101019
# 2  AliceBlue   MN38025    Mhk@9599  1995          1   Gourav  MN101019
# 3  AliceBlue    420795  Gaurav987@  1983          1   Gourav  MN101019

# %%
import matplotlib.pyplot as plt
data = r'C:\Users\goura\Downloads\IPL-Data-Analysis-master\IPL-Data-Analysis-master\matches.csv'
df = pd.read_csv(data)
df.head()
# df.plot()
# plt.show()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Plotting

# %%
print(df.plot())
# print(plt.show)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # Scatter Plot

# %%
df.plot(kind="scatter",x='season',y='win_by_runs')
# Out:
# <AxesSubplot:xlabel='season', ylabel='win_by_runs'>

# %% [markdown]
# # Histogram

# %%
df['season'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
